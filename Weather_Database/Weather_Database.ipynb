# %%
# Import dependencise
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high = 90.000,size = 2000)
lngs = np.random.uniform(low=-180.000,high = 180.000,size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list (lat_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\julie\anaconda3\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\julie\anaconda3\envs\pythondata\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | airai
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | orange cove
# Processing Record 6 of Set 1 | chino valley
# Processing Record 7 of Set 1 | naze
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | severo-kurilsk
# Processing Record 10 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 1 | havoysund
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | novyy yegorlyk
# Processing Record 19 of Set 1 | katherine
# Processing Record 20 of Set 1 | zelenoborskiy
# Processing Record 21 of Set 1 | codrington
# Processing Record 22 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 1 | bara
# Processing Record 24 of Set 1 | estreito
# Processing Record 25 of Set 1 | coquimbo
# Processing Record 26 of Set 1 | luanda
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | kondoa
# Processing Record 36 of Set 1 | akdepe
# Processing Record 37 of Set 1 | manaus
# Processing Record 38 of Set 1 | alta floresta
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | novoorsk
# Processing Record 41 of Set 1 | grong
# Processing Record 42 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 1 | saint-paul
# Processing Record 44 of Set 1 | zhanatas
# City not found. Skipping...
# Processing Record 45 of Set 1 | fairbanks
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | ibra
# Processing Record 49 of Set 1 | xai-xai
# Processing Record 50 of Set 1 | gaoua
# Processing Record 1 of Set 2 | lincoln
# Processing Record 2 of Set 2 | meulaboh
# Processing Record 3 of Set 2 | kaitangata
# Processing Record 4 of Set 2 | souillac
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | akhnur
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | haines junction
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | mecca
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | busko-zdroj
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | aswan
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | esperance
# Processing Record 21 of Set 2 | kamaishi
# Processing Record 22 of Set 2 | portland
# Processing Record 23 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 2 | ucluelet
# Processing Record 25 of Set 2 | benjamin hill
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | sechenovo
# Processing Record 29 of Set 2 | iglesias
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | colquechaca
# Processing Record 32 of Set 2 | ilulissat
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | guaraniacu
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | ushuaia
# Processing Record 37 of Set 2 | sakakah
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | pacific grove
# Processing Record 40 of Set 2 | oktyabrskoye
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 43 of Set 2 | clarksdale
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | aracuai
# Processing Record 47 of Set 2 | bredasdorp
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | inegol
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | tuatapere
# Processing Record 2 of Set 3 | vostok
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | nazca
# Processing Record 5 of Set 3 | basmat
# Processing Record 6 of Set 3 | saint george
# Processing Record 7 of Set 3 | bjerkvik
# Processing Record 8 of Set 3 | oktyabrskiy
# Processing Record 9 of Set 3 | nome
# Processing Record 10 of Set 3 | vrangel
# Processing Record 11 of Set 3 | kencong
# Processing Record 12 of Set 3 | price
# Processing Record 13 of Set 3 | maun
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | skjervoy
# Processing Record 16 of Set 3 | berkak
# Processing Record 17 of Set 3 | praia
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | tokur
# Processing Record 21 of Set 3 | mantua
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | sarakhs
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | gemena
# Processing Record 26 of Set 3 | auki
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 3 | salinopolis
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | mikkeli
# Processing Record 32 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 3 | puerto ayora
# Processing Record 34 of Set 3 | ligayan
# Processing Record 35 of Set 3 | mananara
# Processing Record 36 of Set 3 | nizhneudinsk
# Processing Record 37 of Set 3 | havre
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | constitucion
# Processing Record 40 of Set 3 | virginia beach
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | schwandorf
# Processing Record 43 of Set 3 | san antonio
# Processing Record 44 of Set 3 | liwale
# Processing Record 45 of Set 3 | hawera
# Processing Record 46 of Set 3 | ciudad bolivar
# Processing Record 47 of Set 3 | ranong
# Processing Record 48 of Set 3 | lavrentiya
# Processing Record 49 of Set 3 | tuktoyaktuk
# Processing Record 50 of Set 3 | blagoyevo
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | acapulco
# Processing Record 3 of Set 4 | henties bay
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | touros
# Processing Record 6 of Set 4 | arraial do cabo
# Processing Record 7 of Set 4 | kilindoni
# Processing Record 8 of Set 4 | cadillac
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 4 | lensk
# Processing Record 12 of Set 4 | hong gai
# Processing Record 13 of Set 4 | sasykoli
# Processing Record 14 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 4 | mayo
# Processing Record 16 of Set 4 | almaznyy
# Processing Record 17 of Set 4 | pevek
# Processing Record 18 of Set 4 | dogondoutchi
# Processing Record 19 of Set 4 | changping
# Processing Record 20 of Set 4 | jashpurnagar
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | marsa matruh
# Processing Record 23 of Set 4 | sitka
# Processing Record 24 of Set 4 | poitiers
# Processing Record 25 of Set 4 | bereda
# Processing Record 26 of Set 4 | tiarei
# Processing Record 27 of Set 4 | tretten
# Processing Record 28 of Set 4 | avera
# Processing Record 29 of Set 4 | sorong
# Processing Record 30 of Set 4 | tulagi
# Processing Record 31 of Set 4 | ribeira grande
# Processing Record 32 of Set 4 | wewak
# Processing Record 33 of Set 4 | lima
# Processing Record 34 of Set 4 | deep river
# Processing Record 35 of Set 4 | zambezi
# Processing Record 36 of Set 4 | hobyo
# Processing Record 37 of Set 4 | dikson
# Processing Record 38 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 4 | mutoko
# Processing Record 40 of Set 4 | shangrao
# Processing Record 41 of Set 4 | saint-augustin
# Processing Record 42 of Set 4 | khorramshahr
# Processing Record 43 of Set 4 | chapais
# Processing Record 44 of Set 4 | bayan
# Processing Record 45 of Set 4 | kos
# Processing Record 46 of Set 4 | ritchie
# Processing Record 47 of Set 4 | matay
# Processing Record 48 of Set 4 | arauco
# Processing Record 49 of Set 4 | luangwa
# Processing Record 50 of Set 4 | maniitsoq
# Processing Record 1 of Set 5 | boueni
# Processing Record 2 of Set 5 | mizdah
# Processing Record 3 of Set 5 | skibbereen
# Processing Record 4 of Set 5 | linxia
# Processing Record 5 of Set 5 | roura
# Processing Record 6 of Set 5 | siirt
# Processing Record 7 of Set 5 | natal
# Processing Record 8 of Set 5 | yertsevo
# Processing Record 9 of Set 5 | mangaluru
# Processing Record 10 of Set 5 | deputatskiy
# Processing Record 11 of Set 5 | morales
# Processing Record 12 of Set 5 | christchurch
# Processing Record 13 of Set 5 | hilo
# Processing Record 14 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 15 of Set 5 | bani
# Processing Record 16 of Set 5 | zhigansk
# Processing Record 17 of Set 5 | tabas
# Processing Record 18 of Set 5 | broken hill
# Processing Record 19 of Set 5 | isabela
# Processing Record 20 of Set 5 | elizabeth city
# Processing Record 21 of Set 5 | umm ruwabah
# City not found. Skipping...
# Processing Record 22 of Set 5 | port-gentil
# Processing Record 23 of Set 5 | atambua
# Processing Record 24 of Set 5 | cap malheureux
# Processing Record 25 of Set 5 | grand forks
# Processing Record 26 of Set 5 | aleksandrov gay
# Processing Record 27 of Set 5 | muroto
# Processing Record 28 of Set 5 | longyearbyen
# Processing Record 29 of Set 5 | tongzi
# Processing Record 30 of Set 5 | buy
# Processing Record 31 of Set 5 | pathein
# Processing Record 32 of Set 5 | zhangjiakou
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | kenora
# Processing Record 35 of Set 5 | olsztyn
# Processing Record 36 of Set 5 | khilok
# Processing Record 37 of Set 5 | teguise
# Processing Record 38 of Set 5 | namibe
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | miaga
# Processing Record 41 of Set 5 | tautira
# Processing Record 42 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 5 | katsuura
# Processing Record 44 of Set 5 | kargil
# Processing Record 45 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 47 of Set 5 | yarada
# Processing Record 48 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 5 | gat
# Processing Record 50 of Set 5 | quimper
# Processing Record 1 of Set 6 | omsukchan
# Processing Record 2 of Set 6 | moree
# Processing Record 3 of Set 6 | port elizabeth
# Processing Record 4 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | nhulunbuy
# Processing Record 6 of Set 6 | udachnyy
# Processing Record 7 of Set 6 | labuhan
# Processing Record 8 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 6 | mahebourg
# Processing Record 10 of Set 6 | kasongo-lunda
# Processing Record 11 of Set 6 | kirkwall
# Processing Record 12 of Set 6 | porirua
# Processing Record 13 of Set 6 | shingu
# Processing Record 14 of Set 6 | vestmannaeyjar
# Processing Record 15 of Set 6 | kutum
# Processing Record 16 of Set 6 | mogok
# Processing Record 17 of Set 6 | dickinson
# Processing Record 18 of Set 6 | comodoro rivadavia
# Processing Record 19 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 6 | chumikan
# Processing Record 21 of Set 6 | dudinka
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | kudahuvadhoo
# Processing Record 24 of Set 6 | bathsheba
# Processing Record 25 of Set 6 | alofi
# Processing Record 26 of Set 6 | kautokeino
# Processing Record 27 of Set 6 | alice springs
# Processing Record 28 of Set 6 | bafra
# Processing Record 29 of Set 6 | ila
# Processing Record 30 of Set 6 | san cristobal
# Processing Record 31 of Set 6 | ganzhou
# Processing Record 32 of Set 6 | oum hadjer
# Processing Record 33 of Set 6 | lompoc
# Processing Record 34 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 6 | caravelas
# Processing Record 36 of Set 6 | ketchikan
# Processing Record 37 of Set 6 | hualmay
# Processing Record 38 of Set 6 | new norfolk
# Processing Record 39 of Set 6 | ketchenery
# City not found. Skipping...
# Processing Record 40 of Set 6 | hasaki
# Processing Record 41 of Set 6 | kruisfontein
# Processing Record 42 of Set 6 | mnogovershinnyy
# Processing Record 43 of Set 6 | yulara
# Processing Record 44 of Set 6 | tarauaca
# Processing Record 45 of Set 6 | kerema
# Processing Record 46 of Set 6 | waipawa
# Processing Record 47 of Set 6 | matara
# Processing Record 48 of Set 6 | cooma
# Processing Record 49 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 7 | kadaya
# Processing Record 2 of Set 7 | jiuquan
# Processing Record 3 of Set 7 | nouadhibou
# Processing Record 4 of Set 7 | manokwari
# Processing Record 5 of Set 7 | wahpeton
# Processing Record 6 of Set 7 | olinda
# Processing Record 7 of Set 7 | la palma
# Processing Record 8 of Set 7 | kattivakkam
# Processing Record 9 of Set 7 | leningradskiy
# Processing Record 10 of Set 7 | dancheng
# Processing Record 11 of Set 7 | waingapu
# Processing Record 12 of Set 7 | bandarbeyla
# Processing Record 13 of Set 7 | samarai
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | dingle
# Processing Record 16 of Set 7 | key west
# Processing Record 17 of Set 7 | alamos
# Processing Record 18 of Set 7 | fukue
# Processing Record 19 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 7 | steamboat springs
# Processing Record 22 of Set 7 | ojinaga
# Processing Record 23 of Set 7 | cardston
# Processing Record 24 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 7 | veselynove
# Processing Record 26 of Set 7 | cabedelo
# Processing Record 27 of Set 7 | geraldton
# Processing Record 28 of Set 7 | muzhi
# Processing Record 29 of Set 7 | muisne
# Processing Record 30 of Set 7 | brezice
# Processing Record 31 of Set 7 | eyl
# Processing Record 32 of Set 7 | korla
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | thunder bay
# Processing Record 35 of Set 7 | narsaq
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 7 | teya
# Processing Record 39 of Set 7 | faya
# Processing Record 40 of Set 7 | maracacume
# Processing Record 41 of Set 7 | shenjiamen
# Processing Record 42 of Set 7 | adeje
# Processing Record 43 of Set 7 | ayagoz
# Processing Record 44 of Set 7 | arawa
# Processing Record 45 of Set 7 | nanortalik
# Processing Record 46 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 7 | saint-georges
# Processing Record 48 of Set 7 | fort nelson
# Processing Record 49 of Set 7 | provideniya
# Processing Record 50 of Set 7 | paciran
# Processing Record 1 of Set 8 | cockburn town
# Processing Record 2 of Set 8 | urumqi
# Processing Record 3 of Set 8 | berlevag
# Processing Record 4 of Set 8 | san quintin
# Processing Record 5 of Set 8 | iisalmi
# Processing Record 6 of Set 8 | namatanai
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | palmer
# Processing Record 9 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 10 of Set 8 | salalah
# Processing Record 11 of Set 8 | camacupa
# Processing Record 12 of Set 8 | ambulu
# Processing Record 13 of Set 8 | rongcheng
# Processing Record 14 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 8 | loandjili
# Processing Record 16 of Set 8 | bonga
# Processing Record 17 of Set 8 | houma
# Processing Record 18 of Set 8 | kodiak
# Processing Record 19 of Set 8 | suzhou
# Processing Record 20 of Set 8 | sao joao da barra
# Processing Record 21 of Set 8 | sao filipe
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | hereford
# Processing Record 24 of Set 8 | byron bay
# Processing Record 25 of Set 8 | kununurra
# Processing Record 26 of Set 8 | isangel
# Processing Record 27 of Set 8 | carutapera
# Processing Record 28 of Set 8 | shubarshi
# Processing Record 29 of Set 8 | takoradi
# Processing Record 30 of Set 8 | nortelandia
# Processing Record 31 of Set 8 | dubenskiy
# City not found. Skipping...
# Processing Record 32 of Set 8 | taonan
# Processing Record 33 of Set 8 | russell
# Processing Record 34 of Set 8 | fortuna
# Processing Record 35 of Set 8 | rosaryville
# Processing Record 36 of Set 8 | khatanga
# Processing Record 37 of Set 8 | hamilton
# Processing Record 38 of Set 8 | ballina
# Processing Record 39 of Set 8 | kota belud
# Processing Record 40 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 8 | port blair
# Processing Record 42 of Set 8 | jiaojiang
# Processing Record 43 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 8 | kita
# Processing Record 45 of Set 8 | bouna
# Processing Record 46 of Set 8 | ribeira brava
# Processing Record 47 of Set 8 | kolyubakino
# Processing Record 48 of Set 8 | talara
# Processing Record 49 of Set 8 | asau
# Processing Record 50 of Set 8 | astana
# Processing Record 1 of Set 9 | manta
# Processing Record 2 of Set 9 | rudnichnyy
# Processing Record 3 of Set 9 | mount gambier
# Processing Record 4 of Set 9 | college
# Processing Record 5 of Set 9 | micheweni
# Processing Record 6 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 9 | san patricio
# Processing Record 8 of Set 9 | bheramara
# Processing Record 9 of Set 9 | opuwo
# Processing Record 10 of Set 9 | hervey bay
# Processing Record 11 of Set 9 | itarema
# Processing Record 12 of Set 9 | abu samrah
# Processing Record 13 of Set 9 | tevriz
# Processing Record 14 of Set 9 | tomatlan
# Processing Record 15 of Set 9 | georgetown
# Processing Record 16 of Set 9 | tucuman
# Processing Record 17 of Set 9 | kushima
# Processing Record 18 of Set 9 | passa quatro
# Processing Record 19 of Set 9 | santa rosa
# Processing Record 20 of Set 9 | padang
# Processing Record 21 of Set 9 | la paz
# Processing Record 22 of Set 9 | storforshei
# Processing Record 23 of Set 9 | izumo
# Processing Record 24 of Set 9 | rohri
# Processing Record 25 of Set 9 | chifeng
# Processing Record 26 of Set 9 | ballyshannon
# Processing Record 27 of Set 9 | nemuro
# Processing Record 28 of Set 9 | chichicapam
# City not found. Skipping...
# Processing Record 29 of Set 9 | awbari
# Processing Record 30 of Set 9 | shaowu
# Processing Record 31 of Set 9 | luganville
# Processing Record 32 of Set 9 | tual
# Processing Record 33 of Set 9 | bodden town
# Processing Record 34 of Set 9 | lashio
# Processing Record 35 of Set 9 | port lincoln
# Processing Record 36 of Set 9 | san benito
# Processing Record 37 of Set 9 | vilcun
# Processing Record 38 of Set 9 | torbay
# Processing Record 39 of Set 9 | polunochnoye
# Processing Record 40 of Set 9 | roma
# Processing Record 41 of Set 9 | witrivier
# City not found. Skipping...
# Processing Record 42 of Set 9 | sao goncalo dos campos
# Processing Record 43 of Set 9 | abis
# Processing Record 44 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 9 | sambava
# Processing Record 46 of Set 9 | kokopo
# Processing Record 47 of Set 9 | zhob
# Processing Record 48 of Set 9 | walvis bay
# Processing Record 49 of Set 9 | balagansk
# Processing Record 50 of Set 9 | lebu
# Processing Record 1 of Set 10 | kahului
# Processing Record 2 of Set 10 | muros
# Processing Record 3 of Set 10 | gbarnga
# Processing Record 4 of Set 10 | nehe
# Processing Record 5 of Set 10 | mogadishu
# Processing Record 6 of Set 10 | los llanos de aridane
# Processing Record 7 of Set 10 | belem de sao francisco
# Processing Record 8 of Set 10 | jalu
# Processing Record 9 of Set 10 | altay
# Processing Record 10 of Set 10 | nerchinskiy zavod
# Processing Record 11 of Set 10 | jadu
# Processing Record 12 of Set 10 | rio gallegos
# Processing Record 13 of Set 10 | sovetskiy
# Processing Record 14 of Set 10 | sidi ali
# Processing Record 15 of Set 10 | antsohihy
# Processing Record 16 of Set 10 | teguldet
# Processing Record 17 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 10 | mollendo
# Processing Record 19 of Set 10 | eyemouth
# Processing Record 20 of Set 10 | victoria
# Processing Record 21 of Set 10 | brae
# Processing Record 22 of Set 10 | pokrovsk
# Processing Record 23 of Set 10 | amapa
# Processing Record 24 of Set 10 | jacareacanga
# Processing Record 25 of Set 10 | uruana
# Processing Record 26 of Set 10 | ankpa
# Processing Record 27 of Set 10 | yar-sale
# Processing Record 28 of Set 10 | chicama
# Processing Record 29 of Set 10 | aransas pass
# Processing Record 30 of Set 10 | thessalon
# Processing Record 31 of Set 10 | sechura
# Processing Record 32 of Set 10 | jinchang
# Processing Record 33 of Set 10 | carthage
# Processing Record 34 of Set 10 | salima
# Processing Record 35 of Set 10 | arandis
# Processing Record 36 of Set 10 | cayenne
# Processing Record 37 of Set 10 | lazaro cardenas
# Processing Record 38 of Set 10 | kyrksaeterora
# Processing Record 39 of Set 10 | mbanza-ngungu
# Processing Record 40 of Set 10 | griffith
# Processing Record 41 of Set 10 | smidovich
# Processing Record 42 of Set 10 | merauke
# Processing Record 43 of Set 10 | oistins
# Processing Record 44 of Set 10 | lipin bor
# Processing Record 45 of Set 10 | te anau
# Processing Record 46 of Set 10 | nuuk
# Processing Record 47 of Set 10 | windhoek
# Processing Record 48 of Set 10 | krasnoselkup
# Processing Record 49 of Set 10 | antofagasta
# Processing Record 50 of Set 10 | rio grande
# Processing Record 1 of Set 11 | loralai
# Processing Record 2 of Set 11 | buin
# Processing Record 3 of Set 11 | weligama
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | nouakchott
# Processing Record 6 of Set 11 | cascais
# Processing Record 7 of Set 11 | ngama
# Processing Record 8 of Set 11 | rawson
# Processing Record 9 of Set 11 | puerto leguizamo
# Processing Record 10 of Set 11 | kutahya
# Processing Record 11 of Set 11 | lesozavodsk
# Processing Record 12 of Set 11 | grindavik
# Processing Record 13 of Set 11 | the valley
# Processing Record 14 of Set 11 | tete
# Processing Record 15 of Set 11 | izhevskoye
# Processing Record 16 of Set 11 | vohibinany
# Processing Record 17 of Set 11 | le marin
# Processing Record 18 of Set 11 | kaka
# Processing Record 19 of Set 11 | cam ranh
# Processing Record 20 of Set 11 | macau
# Processing Record 21 of Set 11 | hvide sande
# Processing Record 22 of Set 11 | ribas do rio pardo
# Processing Record 23 of Set 11 | yushan
# Processing Record 24 of Set 11 | karratha
# Processing Record 25 of Set 11 | bilma
# Processing Record 26 of Set 11 | puerto madero
# Processing Record 27 of Set 11 | ostersund
# Processing Record 28 of Set 11 | scarborough
# Processing Record 29 of Set 11 | moussoro
# Processing Record 30 of Set 11 | maceio
# Processing Record 31 of Set 11 | srednekolymsk
# Processing Record 32 of Set 11 | vidim
# Processing Record 33 of Set 11 | bom jardim
# Processing Record 34 of Set 11 | kuminskiy
# Processing Record 35 of Set 11 | charagua
# Processing Record 36 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 37 of Set 11 | young
# Processing Record 38 of Set 11 | rocha
# Processing Record 39 of Set 11 | hofn
# Processing Record 40 of Set 11 | atbasar
# Processing Record 41 of Set 11 | margate
# Processing Record 42 of Set 11 | shenkursk
# Processing Record 43 of Set 11 | jinka
# Processing Record 44 of Set 11 | southbridge
# Processing Record 45 of Set 11 | mitsamiouli
# Processing Record 46 of Set 11 | basoko
# Processing Record 47 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 48 of Set 11 | am timan
# Processing Record 49 of Set 11 | marawi
# Processing Record 50 of Set 11 | maymyo
# Processing Record 1 of Set 12 | urdoma
# Processing Record 2 of Set 12 | abeche
# Processing Record 3 of Set 12 | marystown
# Processing Record 4 of Set 12 | verkh-usugli
# Processing Record 5 of Set 12 | blaj
# Processing Record 6 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 7 of Set 12 | hendaye
# Processing Record 8 of Set 12 | marsaxlokk
# Processing Record 9 of Set 12 | aasiaat
# Processing Record 10 of Set 12 | egvekinot
# Processing Record 11 of Set 12 | noumea
# Processing Record 12 of Set 12 | pareora
# Processing Record 13 of Set 12 | soyaniquilpan
# Processing Record 14 of Set 12 | turangi
# Processing Record 15 of Set 12 | ozuluama
# Processing Record 16 of Set 12 | afogados da ingazeira
# Processing Record 17 of Set 12 | paka
# Processing Record 18 of Set 12 | pangnirtung
# Processing Record 19 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 12 | forecariah
# Processing Record 21 of Set 12 | sola
# Processing Record 22 of Set 12 | laguna
# Processing Record 23 of Set 12 | kysyl-syr
# Processing Record 24 of Set 12 | kabalo
# Processing Record 25 of Set 12 | sobolevo
# Processing Record 26 of Set 12 | quatre cocos
# Processing Record 27 of Set 12 | papasquiaro
# City not found. Skipping...
# Processing Record 28 of Set 12 | sioux lookout
# Processing Record 29 of Set 12 | dieppe
# Processing Record 30 of Set 12 | tigil
# Processing Record 31 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 12 | bafoulabe
# Processing Record 33 of Set 12 | nsanje
# Processing Record 34 of Set 12 | kieta
# Processing Record 35 of Set 12 | ust-uda
# Processing Record 36 of Set 12 | hastings
# Processing Record 37 of Set 12 | tall kayf
# Processing Record 38 of Set 12 | soyo
# Processing Record 39 of Set 12 | ulaangom
# Processing Record 40 of Set 12 | prescott
# Processing Record 41 of Set 12 | dunedin
# Processing Record 42 of Set 12 | axim
# Processing Record 43 of Set 12 | togur
# Processing Record 44 of Set 12 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 12 | culpeper
# Processing Record 46 of Set 12 | kindu
# Processing Record 47 of Set 12 | mount isa
# Processing Record 48 of Set 12 | san andres
# Processing Record 49 of Set 12 | umm kaddadah
# Processing Record 50 of Set 12 | kawardha
# Processing Record 1 of Set 13 | coruripe
# Processing Record 2 of Set 13 | anadyr
# Processing Record 3 of Set 13 | horodnytsya
# Processing Record 4 of Set 13 | godeanu
# Processing Record 5 of Set 13 | burnie
# Processing Record 6 of Set 13 | madinat sittah uktubar
# Processing Record 7 of Set 13 | vardo
# Processing Record 8 of Set 13 | ust-kuyga
# Processing Record 9 of Set 13 | gerstetten
# Processing Record 10 of Set 13 | pirenopolis
# Processing Record 11 of Set 13 | oriximina
# Processing Record 12 of Set 13 | coolum beach
# Processing Record 13 of Set 13 | wad madani
# Processing Record 14 of Set 13 | baniachang
# Processing Record 15 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 16 of Set 13 | jertih
# Processing Record 17 of Set 13 | bambari
# Processing Record 18 of Set 13 | sept-iles
# Processing Record 19 of Set 13 | simao dias
# Processing Record 20 of Set 13 | alekseyevsk
# Processing Record 21 of Set 13 | keshan
# City not found. Skipping...
# Processing Record 22 of Set 13 | puerto escondido
# Processing Record 23 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 13 | camocim
# Processing Record 25 of Set 13 | adrar
# Processing Record 26 of Set 13 | kapit
# Processing Record 27 of Set 13 | luderitz
# Processing Record 28 of Set 13 | bhatkal
# Processing Record 29 of Set 13 | garissa
# Processing Record 30 of Set 13 | juiz de fora
# Processing Record 31 of Set 13 | ulladulla
# Processing Record 32 of Set 13 | gombe
# Processing Record 33 of Set 13 | bobrovytsya
# Processing Record 34 of Set 13 | vieksniai
# Processing Record 35 of Set 13 | puerto baquerizo moreno
# Processing Record 36 of Set 13 | paamiut
# Processing Record 37 of Set 13 | channel-port aux basques
# Processing Record 38 of Set 13 | maragogi
# Processing Record 39 of Set 13 | promyshlennyy
# Processing Record 40 of Set 13 | woodward
# Processing Record 41 of Set 13 | wittlich
# Processing Record 42 of Set 13 | leh
# Processing Record 43 of Set 13 | komsomolskiy
# Processing Record 44 of Set 13 | mezen
# Processing Record 45 of Set 13 | hue
# Processing Record 46 of Set 13 | santa isabel do rio negro
# Processing Record 47 of Set 13 | keti bandar
# Processing Record 48 of Set 13 | smoky lake
# Processing Record 49 of Set 13 | bukachacha
# Processing Record 50 of Set 13 | barabai
# Processing Record 1 of Set 14 | kimberley
# Processing Record 2 of Set 14 | flinders
# Processing Record 3 of Set 14 | praia da vitoria
# Processing Record 4 of Set 14 | langsa
# Processing Record 5 of Set 14 | paine
# Processing Record 6 of Set 14 | pinawa
# Processing Record 7 of Set 14 | port hedland
# Processing Record 8 of Set 14 | tukrah
# Processing Record 9 of Set 14 | clifton
# Processing Record 10 of Set 14 | lichinga
# Processing Record 11 of Set 14 | pasighat
# Processing Record 12 of Set 14 | sistranda
# Processing Record 13 of Set 14 | arlit
# Processing Record 14 of Set 14 | aksu
# Processing Record 15 of Set 14 | ostrovnoy
# Processing Record 16 of Set 14 | turukhansk
# Processing Record 17 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 14 | tromso
# Processing Record 19 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 20 of Set 14 | veraval
# Processing Record 21 of Set 14 | pinheiro machado
# Processing Record 22 of Set 14 | jardim
# Processing Record 23 of Set 14 | black diamond
# Processing Record 24 of Set 14 | umm lajj
# Processing Record 25 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 26 of Set 14 | bowen
# Processing Record 27 of Set 14 | muravlenko
# Processing Record 28 of Set 14 | carroll
# Processing Record 29 of Set 14 | baisha
# Processing Record 30 of Set 14 | gunnedah
# Processing Record 31 of Set 14 | huoqiu
# Processing Record 32 of Set 14 | champasak
# Processing Record 33 of Set 14 | aban
# Processing Record 34 of Set 14 | abastumani
# Processing Record 35 of Set 14 | kyaukse
# Processing Record 36 of Set 14 | oussouye
# Processing Record 37 of Set 14 | verkhnevilyuysk
# Processing Record 38 of Set 14 | iguai
# Processing Record 39 of Set 14 | saint-leu
# Processing Record 40 of Set 14 | caluquembe
# Processing Record 41 of Set 14 | matane
# Processing Record 42 of Set 14 | imbituba
# Processing Record 43 of Set 14 | santa ines
# Processing Record 44 of Set 14 | mitu
# Processing Record 45 of Set 14 | husavik
# Processing Record 46 of Set 14 | voh
# Processing Record 47 of Set 14 | port pirie
# Processing Record 48 of Set 14 | rio claro
# Processing Record 49 of Set 14 | newport
# Processing Record 50 of Set 14 | alexandria
# Processing Record 1 of Set 15 | payo
# Processing Record 2 of Set 15 | eureka
# Processing Record 3 of Set 15 | liaozhong
# Processing Record 4 of Set 15 | paramonga
# Processing Record 5 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 15 | bogorodskoye
# Processing Record 7 of Set 15 | bayeux
# Processing Record 8 of Set 15 | kepala batas
# Processing Record 9 of Set 15 | reitz
# Processing Record 10 of Set 15 | galeana
# Processing Record 11 of Set 15 | wanning
# Processing Record 12 of Set 15 | aleppo
# Processing Record 13 of Set 15 | belmonte
# Processing Record 14 of Set 15 | syracuse
# Processing Record 15 of Set 15 | okhotsk
# Processing Record 16 of Set 15 | izhma
# Processing Record 17 of Set 15 | atakpame
# Processing Record 18 of Set 15 | dong xoai
# Processing Record 19 of Set 15 | beira
# Processing Record 20 of Set 15 | tezu
# Processing Record 21 of Set 15 | hidalgo
# Processing Record 22 of Set 15 | elbistan
# Processing Record 23 of Set 15 | north platte
# Processing Record 24 of Set 15 | celestun
# Processing Record 25 of Set 15 | scheia
# Processing Record 26 of Set 15 | xuddur
# Processing Record 27 of Set 15 | strezhevoy
# Processing Record 28 of Set 15 | richards bay
# Processing Record 29 of Set 15 | drumnadrochit
# Processing Record 30 of Set 15 | zhoucheng
# Processing Record 31 of Set 15 | sakaiminato
# Processing Record 32 of Set 15 | troitskoye
# Processing Record 33 of Set 15 | black river
# Processing Record 34 of Set 15 | san luis
# Processing Record 35 of Set 15 | jumla
# Processing Record 36 of Set 15 | benghazi
# Processing Record 37 of Set 15 | ta khmau
# Processing Record 38 of Set 15 | stornoway
# Processing Record 39 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 40 of Set 15 | la pintada
# Processing Record 41 of Set 15 | pamfila
# Processing Record 42 of Set 15 | bathurst
# Processing Record 43 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 44 of Set 15 | gijon
# Processing Record 45 of Set 15 | sikasso
# Processing Record 46 of Set 15 | anloga
# Processing Record 47 of Set 15 | albertville
# Processing Record 48 of Set 15 | bage
# Processing Record 49 of Set 15 | picota
# Processing Record 50 of Set 15 | akureyri
# Processing Record 1 of Set 16 | port macquarie
# Processing Record 2 of Set 16 | gua musang
# Processing Record 3 of Set 16 | dwarka
# Processing Record 4 of Set 16 | tura
# Processing Record 5 of Set 16 | husainabad
# Processing Record 6 of Set 16 | pochutla
# Processing Record 7 of Set 16 | vuktyl
# Processing Record 8 of Set 16 | kaspiyskiy
# Processing Record 9 of Set 16 | bihoro
# Processing Record 10 of Set 16 | aqtobe
# Processing Record 11 of Set 16 | payakumbuh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     45.48        95          83
# 1         Airai      TL  -8.9266  125.4092     62.73        68          92
# 2  Punta Arenas      CL -53.1500  -70.9167     46.51        81          75
# 3     Busselton      AU -33.6500  115.3333     59.40        73         100
# 4   Orange Cove      US  36.6244 -119.3137     97.97        14           1
#
#    Wind Speed Current Description
# 0       14.09          light rain
# 1        3.71     overcast clouds
# 2        6.91          light rain
# 3       19.93     overcast clouds
# 4        7.23           clear sky

# %%
# Create the output file (CSV).new_file = "folder_name/file_name". Need to create folder name first
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
